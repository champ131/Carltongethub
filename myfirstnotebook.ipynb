# %%
name = input("what's your name?")
age = input("How old are you?")

print("Hello, " + name + "!")
print()
print("You are " + age +" years old.")
# Out:
# Hello, carl!
#
# You are 38 years old.

# %%
a = 32    #Initialize the value of a
b = 6     #Initialize the value of b

print("addition of two numbers:",a+b)
print(" Subtraction of two numbers:" ,a*b)
print(" Division of two numbers:",a/b)
print("Reminder of two numbers:",a%b)
print("Exponent of two numbers:",a**b)
print("Floor division of two numbers:",a//b)
multipleOperators = 1 + 2 * 3 / 4.0
print("resluts of multipleoperators is",multipleOperators)
# Out:
# addition of two numbers: 38
#  Subtraction of two numbers: 192
#  Division of two numbers: 5.333333333333333
# Reminder of two numbers: 2
# Exponent of two numbers: 1073741824
# Floor division of two numbers: 5
# resluts of multipleoperators is 2.5

# %% [markdown]
# Operator
# Example
# Equivalent to
# =
# x=y
# x=y
# +=
# x+=y
# x=x+y
# -=
# x-=y
# x=x-y
# *=
# x*=y
# x=x*y
# /=
# x/=y
# x=x/y
# %=
# x%=y![image.png](attachment:image.png)
# x=x%y
#
#
#
# Assignment operators are used to assign values to variables and are used for modifying a value, performing some mathematical calculations, and assigning values to the variable.
# If the value already exists in the variable, it is overwritten by the assignment operator (=).
